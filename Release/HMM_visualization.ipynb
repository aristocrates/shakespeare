# %%
import os
from IPython.display import HTML
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)
import shakespeare_hmm

# %% [markdown]
# ### Wordcloud for all of the poems

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %% [markdown]
# ### Train the HMM

# %%
shakespearean_hmm, sonnet = shakespeare_hmm.do_hmm(verbose = False, give_hmm = True)

# %%
shakespeare_hmm.token2index
# Out:
# {'worms': 0,
#  'the perfect': 1,
#  'sharp': 2,
#  'purity': 3,
#  'precious': 4,
#  'desert': 5,
#  'sound': 6,
#  'paws': 7,
#  'the boy': 8,
#  'shamed': 9,
#  'crests': 10,
#  'the dedicated': 11,
#  'require': 12,
#  'extreme': 13,
#  'the morning': 14,
#  'perhaps': 15,
#  'boat': 16,
#  'feasts': 17,
#  'heard': 18,
#  'sake': 19,
#  'without': 20,
#  'point': 21,
#  'possession': 22,
#  'a second': 23,
#  'affairs': 24,
#  'wishing': 25,
#  'make': 26,
#  'darkening': 27,
#  'pursuing': 28,
#  'dote': 29,
#  'present-absent': 30,
#  'cry': 31,
#  'discloses': 32,
#  'dead': 33,
#  'becoming': 34,
#  'plain': 35,
#  'unfair': 36,
#  'admired': 37,
#  'forsaken': 38,
#  'eased': 39,
#  'son': 40,
#  'count': 41,
#  'herald': 42,
#  'slandered': 43,
#  "mind's": 44,
#  'bird': 45,
#  'fierce': 46,
#  'the brave': 47,
#  'owes': 48,
#  'vile': 49,
#  'the physician': 50,
#  'the strength': 51,
#  'bent': 52,
#  'sorrows': 53,
#  'greet': 54,
#  'placed': 55,
#  'words': 56,
#  'strengthened': 57,
#  'flame': 58,
#  "a widow's": 59,
#  'charged': 60,
#  'well-contented': 61,
#  'the counterfeit': 62,
#  'never-resting': 63,
#  'feast': 64,
#  'the region': 65,
#  'once': 66,
#  'astonished': 67,
#  'adore': 68,
#  'hers': 69,
#  'yore': 70,
#  'the mountain': 71,
#  'a thing': 72,
#  'candles': 73,
#  'hath': 74,
#  'erred': 75,
#  'ever': 76,
#  'speechless': 77,
#  'blunting': 78,
#  'the gilded': 79,
#  'desiring': 80,
#  'registers': 81,
#  'slain': 82,
#  'robbing': 83,
#  'aside': 84,
#  'patient': 85,
#  'shape': 86,
#  'saying': 87,
#  'counting': 88,
#  'the tenth': 89,
#  'doubting': 90,
#  'picture': 91,
#  'older': 92,
#  'thus': 93,
#  'hope': 94,
#  'loves': 95,
#  'forsworn': 96,
#  'reigned': 97,
#  'turns': 98,
#  'intelligence': 99,
#  'numbers': 100,
#  'a house': 101,
#  'truths': 102,
#  'character': 103,
#  'lays': 104,
#  'richer': 105,
#  'a healthful': 106,
#  'touch': 107,
#  'wires': 108,
#  'confounding': 109,
#  'derive': 110,
#  'the forlorn': 111,
#  'drooping': 112,
#  'a salve': 113,
#  'gifts': 114,
#  'the thing': 115,
#  'breed': 116,
#  'the other': 117,
#  'says': 118,
#  'indirectly': 119,
#  'did': 120,
#  'changing': 121,
#  'a tomb': 122,
#  'achieve': 123,
#  'enlighten': 124,
#  'presence': 125,
#  'lends': 126,
#  'painting': 127,
#  'touched': 128,
#  'woes': 129,
#  'parts': 130,
#  'a date': 131,
#  'the power': 132,
#  'cured': 133,
#  'tyrants': 134,
#  'bud': 135,
#  'drudge': 136,
#  'gravity': 137,
#  'dial': 138,
#  'quickly': 139,
#  'befits': 140,
#  'respect': 141,
#  'content': 142,
#  'unkind': 143,
#  'the more': 144,
#  'affords': 145,
#  'the forward': 146,
#  'a gilded': 147,
#  'siren': 148,
#  'attending': 149,
#  'foe': 150,
#  'rude': 151,
#  'their': 152,
#  'cross': 153,
#  'stones': 154,
#  'a tattered': 155,
#  'mixed': 156,
#  'untrue': 157,
#  'blood': 158,
#  'extant': 159,
#  'rain': 160,
#  'spheres': 161,
#  'o': 162,
#  'few': 163,
#  'heart': 164,
#  'hoisted': 165,
#  'equal': 166,
#  'the miles': 167,
#  'interchange': 168,
#  'a bastard': 169,
#  'constant': 170,
#  'worse': 171,
#  'immortal': 172,
#  'maiden': 173,
#  'pointing': 174,
#  'motion': 175,
#  'reasons': 176,
#  'wink': 177,
#  'alien': 178,
#  'receives': 179,
#  'blessed-fair': 180,
#  'the ear': 181,
#  'soft': 182,
#  'faint': 183,
#  'a common': 184,
#  'interim': 185,
#  'nursed': 186,
#  'sighs': 187,
#  'times': 188,
#  'drawn': 189,
#  'anew': 190,
#  'the painted': 191,
#  'describe': 192,
#  'lips': 193,
#  'the general': 194,
#  'reign': 195,
#  'fast': 196,
#  'authorizing': 197,
#  'the wastes': 198,
#  'summon': 199,
#  'since': 200,
#  'an': 201,
#  "eye's": 202,
#  'marble': 203,
#  'living': 204,
#  'tattered': 205,
#  'injurious': 206,
#  'faith': 207,
#  'fairest': 208,
#  'the sober': 209,
#  'alone': 210,
#  'used': 211,
#  'privilege': 212,
#  'the stormy': 213,
#  'guides': 214,
#  'broke': 215,
#  'gusts': 216,
#  'a goddess': 217,
#  'divine': 218,
#  'disarmed': 219,
#  'beds': 220,
#  'yea': 221,
#  'most': 222,
#  'composed': 223,
#  'warning': 224,
#  'reproach': 225,
#  'awake': 226,
#  'deem': 227,
#  'root': 228,
#  'else': 229,
#  'the edge': 230,
#  'a bliss': 231,
#  'visage': 232,
#  'brood': 233,
#  'rebel': 234,
#  'riot': 235,
#  'enforced': 236,
#  'vowed': 237,
#  'altered': 238,
#  'mouthed': 239,
#  'dimmed': 240,
#  'another': 241,
#  'besiege': 242,
#  'treason': 243,
#  'grows': 244,
#  'this': 245,
#  'mended': 246,
#  'the forests': 247,
#  'tickled': 248,
#  'only': 249,
#  'how': 250,
#  'abide': 251,
#  'goddess': 252,
#  'eternal': 253,
#  'usury': 254,
#  'the true': 255,
#  'prescriptions': 256,
#  'ceremony': 257,
#  'hast': 258,
#  'spend': 259,
#  'gored': 260,
#  'stars': 261,
#  'tenure': 262,
#  'twenty': 263,
#  'streams': 264,
#  'justify': 265,
#  'thou': 266,
#  "the monarch's": 267,
#  'over-plus': 268,
#  'drugs': 269,
#  'youth': 270,
#  'truly': 271,
#  'injury': 272,
#  'love': 273,
#  'spoil': 274,
#  'weeds': 275,
#  'shines': 276,
#  'keen': 277,
#  'graced': 278,
#  'phrase': 279,
#  "self's": 280,
#  'the hours': 281,
#  'riches': 282,
#  'fickle': 283,
#  'distills': 284,
#  'expiate': 285,
#  'morn': 286,
#  'alive': 287,
#  'essays': 288,
#  'potions': 289,
#  'crime': 290,
#  "the owner's": 291,
#  'feed': 292,
#  'barren': 293,
#  'the drops': 294,
#  'difference': 295,
#  'shake': 296,
#  'determination': 297,
#  'instant': 298,
#  'save': 299,
#  'line': 300,
#  'rosy': 301,
#  'in': 302,
#  'about': 303,
#  'must': 304,
#  'into': 305,
#  'hid': 306,
#  'tyranny': 307,
#  'a face': 308,
#  'pass': 309,
#  'deceive': 310,
#  'lean': 311,
#  'revolt': 312,
#  'soil': 313,
#  'lovers': 314,
#  'brave': 315,
#  'countenance': 316,
#  'applying': 317,
#  'learning': 318,
#  'lest': 319,
#  'cheeks': 320,
#  'well-tuned': 321,
#  'world': 322,
#  'forty': 323,
#  'love-god': 324,
#  'services': 325,
#  'jade': 326,
#  'shook': 327,
#  'herein': 328,
#  'slay': 329,
#  'do': 330,
#  'feil': 331,
#  'sport': 332,
#  'full': 333,
#  'image': 334,
#  'indigest': 335,
#  'varying': 336,
#  'the gentle': 337,
#  'fore-bemoaned': 338,
#  'dry': 339,
#  'try': 340,
#  'master': 341,
#  "world's": 342,
#  'say': 343,
#  'always': 344,
#  'outlive': 345,
#  'a sovereign': 346,
#  'writes': 347,
#  'are': 348,
#  'coming': 349,
#  'burden': 350,
#  'locked': 351,
#  'commit': 352,
#  'remembered': 353,
#  'copy': 354,
#  'princes': 355,
#  'confound': 356,
#  'towards': 357,
#  'dearth': 358,
#  'rhetoric': 359,
#  'spirit': 360,
#  'mow': 361,
#  'wet': 362,
#  "men's": 363,
#  'fall': 364,
#  'possessing': 365,
#  'the sweetest': 366,
#  'adverse': 367,
#  'pity-wanting': 368,
#  'masked': 369,
#  'hairs': 370,
#  'prone': 371,
#  'dying': 372,
#  'suspect': 373,
#  'restored': 374,
#  'preserve': 375,
#  'fever': 376,
#  'drink': 377,
#  'the bay': 378,
#  'bark': 379,
#  'sunk': 380,
#  'controlling': 381,
#  'idolatry': 382,
#  'recompense': 383,
#  'the hardest': 384,
#  'the joy': 385,
#  "'tis": 386,
#  'the cold': 387,
#  'issue': 388,
#  'redeem': 389,
#  'the voice': 390,
#  'patience': 391,
#  'a lease': 392,
#  'worship': 393,
#  'over-goes': 394,
#  'impregnable': 395,
#  'finds': 396,
#  'universe': 397,
#  'forbid': 398,
#  'persuade': 399,
#  'hue': 400,
#  'whom': 401,
#  'featured': 402,
#  'shame': 403,
#  'honest': 404,
#  'desired': 405,
#  'use': 406,
#  'the constancy': 407,
#  'prophecies': 408,
#  'sweetness': 409,
#  'pupil': 410,
#  'pluck': 411,
#  'torn': 412,
#  'past': 413,
#  'grown': 414,
#  'kindness': 415,
#  'climbed': 416,
#  'husband': 417,
#  'longing': 418,
#  'expired': 419,
#  'advised': 420,
#  'junes': 421,
#  'forgot': 422,
#  'rough': 423,
#  'died': 424,
#  'thorns': 425,
#  'shun': 426,
#  'new-appearing': 427,
#  'rich': 428,
#  'the lays': 429,
#  'captain': 430,
#  'comes': 431,
#  'doubt': 432,
#  'endless': 433,
#  'keep': 434,
#  'poets': 435,
#  'stealing': 436,
#  'any': 437,
#  'a new': 438,
#  'note': 439,
#  'the rarities': 440,
#  'the disgrace': 441,
#  'hymn': 442,
#  'fearing': 443,
#  'looked': 444,
#  'foes': 445,
#  'the wise': 446,
#  'delayed': 447,
#  'songs': 448,
#  'rents': 449,
#  'figured': 450,
#  'neck': 451,
#  'took': 452,
#  'hasten': 453,
#  'array': 454,
#  'the seasons': 455,
#  'phoenix': 456,
#  'knowing': 457,
#  'brought': 458,
#  'confined': 459,
#  'sour': 460,
#  'forgetful': 461,
#  'the rich': 462,
#  'theirs': 463,
#  'passion': 464,
#  'concord': 465,
#  'invent': 466,
#  'bastard': 467,
#  'rehearse': 468,
#  'envy': 469,
#  'steep': 470,
#  'frequent': 471,
#  'one': 472,
#  'a bath': 473,
#  'thoughts': 474,
#  'trifle': 475,
#  'the breath': 476,
#  'dearer': 477,
#  "love's": 478,
#  'trifles': 479,
#  'end': 480,
#  'breeds': 481,
#  'coral': 482,
#  'a lamb': 483,
#  'curse': 484,
#  'the frame': 485,
#  'wasteful': 486,
#  'a journey': 487,
#  'glory': 488,
#  'new-fangled': 489,
#  'silence': 490,
#  'works': 491,
#  'chief': 492,
#  'the pleasure': 493,
#  'needs': 494,
#  'too': 495,
#  'low': 496,
#  'impair': 497,
#  'provide': 498,
#  'the chronicle': 499,
#  'confess': 500,
#  'meant': 501,
#  'deceived': 502,
#  'score': 503,
#  'feathered': 504,
#  'compounded': 505,
#  'fresher': 506,
#  'strength': 507,
#  'despised': 508,
#  'hands': 509,
#  'dates': 510,
#  'angel': 511,
#  'loving': 512,
#  'toiled': 513,
#  'physicians': 514,
#  'accents': 515,
#  'such': 516,
#  'argument': 517,
#  'bell': 518,
#  'if': 519,
#  'hurt': 520,
#  'being': 521,
#  'weary': 522,
#  'expressing': 523,
#  'leave': 524,
#  'made': 525,
#  'kept': 526,
#  "there's": 527,
#  'plot': 528,
#  'sufficed': 529,
#  'a dial': 530,
#  'his': 531,
#  'clay': 532,
#  'servant': 533,
#  'theft': 534,
#  'monsters': 535,
#  'chide': 536,
#  'wonder': 537,
#  'define': 538,
#  'denote': 539,
#  'lack': 540,
#  'a form': 541,
#  'rocks': 542,
#  'young': 543,
#  'the heaven': 544,
#  'duty': 545,
#  'ten': 546,
#  'change': 547,
#  'mercy': 548,
#  'the mouths': 549,
#  'some': 550,
#  'begins': 551,
#  'the stern': 552,
#  'strained': 553,
#  'ghastly': 554,
#  'account': 555,
#  'who': 556,
#  'subject': 557,
#  'at': 558,
#  'sullen': 559,
#  'tears': 560,
#  'hold': 561,
#  'belong': 562,
#  'mistress': 563,
#  'lilies': 564,
#  'annexed': 565,
#  'sad': 566,
#  'feature': 567,
#  'the eyes': 568,
#  'married': 569,
#  'scorned': 570,
#  'the very': 571,
#  'common': 572,
#  'the peace': 573,
#  'dreading': 574,
#  'augurs': 575,
#  'wit': 576,
#  'adjunct': 577,
#  "heart's": 578,
#  'judgment': 579,
#  'the canker': 580,
#  'vexed': 581,
#  'defence': 582,
#  'followed': 583,
#  'alas': 584,
#  'enjoys': 585,
#  'eager': 586,
#  'policy': 587,
#  'the thought': 588,
#  'the tyrants': 589,
#  'testy': 590,
#  'sinks': 591,
#  'eyed': 592,
#  'same': 593,
#  'sympathized': 594,
#  'there': 595,
#  'both': 596,
#  'storm-beaten': 597,
#  "i'll": 598,
#  'healthful': 599,
#  'the little': 600,
#  'bright': 601,
#  'rather': 602,
#  'hot': 603,
#  'checked': 604,
#  'confounds': 605,
#  'wantonly': 606,
#  'much': 607,
#  'head': 608,
#  'hearts': 609,
#  'mar': 610,
#  'the soil': 611,
#  'wooing': 612,
#  'profit': 613,
#  'smell': 614,
#  'rising': 615,
#  'posting': 616,
#  'dancing': 617,
#  'the sun': 618,
#  'course': 619,
#  'moment': 620,
#  'thing': 621,
#  'the time': 622,
#  'ill-wresting': 623,
#  'a frown': 624,
#  'rid': 625,
#  'ruth': 626,
#  'praise': 627,
#  'steal': 628,
#  'strange': 629,
#  'divining': 630,
#  'a mansion': 631,
#  'grossly': 632,
#  'years': 633,
#  'scandal': 634,
#  'act': 635,
#  'complain': 636,
#  'diseased': 637,
#  'the ground': 638,
#  'the ill': 639,
#  'a deceived': 640,
#  'nothing': 641,
#  'vanishing': 642,
#  'glance': 643,
#  'grace': 644,
#  'weed': 645,
#  'oppressed': 646,
#  'compile': 647,
#  'penance': 648,
#  'beloved': 649,
#  'betwixt': 650,
#  'sway': 651,
#  'images': 652,
#  'a modern': 653,
#  'term': 654,
#  'the violet': 655,
#  'assured': 656,
#  'fading': 657,
#  'flattered': 658,
#  'indeed': 659,
#  'abundant': 660,
#  'lust': 661,
#  'lo': 662,
#  'the prime': 663,
#  'wards': 664,
#  'herself': 665,
#  'filled': 666,
#  'ruminate': 667,
#  'the deep': 668,
#  'seek': 669,
#  'fairer': 670,
#  'obsequious': 671,
#  'spirits': 672,
#  'brass': 673,
#  'prisoner': 674,
#  'call': 675,
#  'writers': 676,
#  'behold': 677,
#  'beautiful': 678,
#  'a glorious': 679,
#  'win': 680,
#  'joy': 681,
#  'the place': 682,
#  'invoked': 683,
#  'the bath': 684,
#  'sought': 685,
#  'the prey': 686,
#  'already': 687,
#  'whatsoever': 688,
#  'seconds': 689,
#  'rack': 690,
#  'mournful': 691,
#  'entertain': 692,
#  'nightly': 693,
#  'bred': 694,
#  'advocate': 695,
#  'fled': 696,
#  'betray': 697,
#  'least': 698,
#  'lives': 699,
#  'wherein': 700,
#  'breath': 701,
#  'unseen': 702,
#  'the weary': 703,
#  'sins': 704,
#  'respects': 705,
#  'mind': 706,
#  'sunken': 707,
#  'them': 708,
#  'stamped': 709,
#  'the injuries': 710,
#  'prognosticate': 711,
#  'rest': 712,
#  'ruin': 713,
#  'enfeebled': 714,
#  'inherit': 715,
#  'predict': 716,
#  'the charter': 717,
#  'mourners': 718,
#  'gems': 719,
#  'number': 720,
#  'mad': 721,
#  "fortune's": 722,
#  'the east': 723,
#  'entitled': 724,
#  'over-partial': 725,
#  'hooks': 726,
#  'despise': 727,
#  'monument': 728,
#  'the lesson': 729,
#  'the summer': 730,
#  'those': 731,
#  'invention': 732,
#  'active': 733,
#  'bond': 734,
#  'crowning': 735,
#  'goodly': 736,
#  'vacant': 737,
#  'antiquity': 738,
#  'taught': 739,
#  'true': 740,
#  'traffic': 741,
#  'imitated': 742,
#  'wrong': 743,
#  'chips': 744,
#  'nurse': 745,
#  "friend's": 746,
#  'example': 747,
#  'nourished': 748,
#  'evermore': 749,
#  'thine': 750,
#  'therefore': 751,
#  'teach': 752,
#  'the best': 753,
#  'horse': 754,
#  'above': 755,
#  'the prophetic': 756,
#  'should': 757,
#  'majesty': 758,
#  'chiding': 759,
#  'saturn': 760,
#  'reason': 761,
#  'wind': 762,
#  'enough': 763,
#  'assure': 764,
#  'art': 765,
#  'sire': 766,
#  'friend': 767,
#  'suppose': 768,
#  'sacred': 769,
#  'lame': 770,
#  'oppression': 771,
#  'contrary': 772,
#  'inhabit': 773,
#  'maintain': 774,
#  'wills': 775,
#  'surmount': 776,
#  'double-vantage': 777,
#  'a living': 778,
#  'thence': 779,
#  'the blind': 780,
#  'while': 781,
#  'hour': 782,
#  'task': 783,
#  'sinful': 784,
#  'bears': 785,
#  'wish': 786,
#  'the way': 787,
#  'the ornament': 788,
#  'proves': 789,
#  'wondrous': 790,
#  'live': 791,
#  'the humble': 792,
#  'limbs': 793,
#  'please': 794,
#  'cools': 795,
#  'growing': 796,
#  'ladies': 797,
#  'the lily': 798,
#  'perceived': 799,
#  'new-found': 800,
#  'mute': 801,
#  'the sad': 802,
#  'leases': 803,
#  'vermilion': 804,
#  'worthy': 805,
#  'entombed': 806,
#  'the distraction': 807,
#  'father': 808,
#  'fountains': 809,
#  'the ending': 810,
#  'admitted': 811,
#  'sick': 812,
#  'a twofold': 813,
#  'releasing': 814,
#  'own': 815,
#  'come': 816,
#  'themes': 817,
#  'everywhere': 818,
#  'travel': 819,
#  'sequent': 820,
#  'chase': 821,
#  'children': 822,
#  'variation': 823,
#  'dart': 824,
#  'grieved': 825,
#  'takes': 826,
#  'undivided': 827,
#  'wastes': 828,
#  'trust': 829,
#  'brightness': 830,
#  'random': 831,
#  'open': 832,
#  'afar': 833,
#  'forced': 834,
#  "a poet's": 835,
#  'assistance': 836,
#  'a better': 837,
#  'distilled': 838,
#  'false': 839,
#  'the wind': 840,
#  'themselves': 841,
#  'millions': 842,
#  'fiend': 843,
#  'former': 844,
#  'learned': 845,
#  'spends': 846,
#  'a devil': 847,
#  'mortal': 848,
#  'stronger': 849,
#  'unhappily': 850,
#  'hated': 851,
#  'held': 852,
#  "the lily's": 853,
#  'belongs': 854,
#  'frowns': 855,
#  'unmoved': 856,
#  'defect': 857,
#  'bending': 858,
#  'hand': 859,
#  "helen's": 860,
#  'bait': 861,
#  'fine': 862,
#  'ornament': 863,
#  'conquest': 864,
#  'up-locked': 865,
#  'straying': 866,
#  'deaths': 867,
#  'the clear': 868,
#  'grounded': 869,
#  'guilty': 870,
#  'suffers': 871,
#  'a babe': 872,
#  'senses': 873,
#  'bear': 874,
#  'strive': 875,
#  'doctor-like': 876,
#  'skill': 877,
#  'the age': 878,
#  'showers': 879,
#  'the heart': 880,
#  'ragged': 881,
#  'absent': 882,
#  'thrice': 883,
#  'contain': 884,
#  'the night': 885,
#  'the statute': 886,
#  'souls': 887,
#  'quest': 888,
#  'misuse': 889,
#  "the sun's": 890,
#  'decree': 891,
#  'temperate': 892,
#  'lost': 893,
#  'the subject': 894,
#  'away': 895,
#  'dreaming': 896,
#  'a brand': 897,
#  'the treasure': 898,
#  'share': 899,
#  'perforce': 900,
#  'teeth': 901,
#  'repent': 902,
#  'thereof': 903,
#  'constancy': 904,
#  'the keen': 905,
#  'hammered': 906,
#  'exchanged': 907,
#  'strikes': 908,
#  'a wondrous': 909,
#  'yet': 910,
#  'aye': 911,
#  'proposed': 912,
#  'assailed': 913,
#  'feasting': 914,
#  'defeated': 915,
#  'the banks': 916,
#  'long': 917,
#  'rolling': 918,
#  'the lovely': 919,
#  'prime': 920,
#  'control': 921,
#  'sickness': 922,
#  'sing': 923,
#  'seems': 924,
#  'express': 925,
#  'ills': 926,
#  'the orient': 927,
#  'alike': 928,
#  'prove': 929,
#  'serving': 930,
#  'praised': 931,
#  'darkness': 932,
#  'spur': 933,
#  'the surly': 934,
#  'the marriage': 935,
#  'costly': 936,
#  'minion': 937,
#  'absence': 938,
#  'the number': 939,
#  'yours': 940,
#  'proved': 941,
#  'revenge': 942,
#  'gulls': 943,
#  'pen': 944,
#  'sail': 945,
#  'hard': 946,
#  'the lawful': 947,
#  'disposed': 948,
#  "sea's": 949,
#  'pitied': 950,
#  'stout': 951,
#  'fire': 952,
#  'sometimes': 953,
#  'the spring': 954,
#  'way': 955,
#  'gain': 956,
#  'rights': 957,
#  'told': 958,
#  'determined': 959,
#  'presage': 960,
#  'the loss': 961,
#  'saucy': 962,
#  'sets': 963,
#  'mistake': 964,
#  'bare': 965,
#  'the shore': 966,
#  'infection': 967,
#  'have': 968,
#  'semblance': 969,
#  'hatred': 970,
#  'stone': 971,
#  "time's": 972,
#  'office': 973,
#  'cease': 974,
#  'wake': 975,
#  'consider': 976,
#  'anchored': 977,
#  "husband's": 978,
#  'register': 979,
#  'hunted': 980,
#  'flower': 981,
#  'the proud': 982,
#  'four': 983,
#  'ignorance': 984,
#  'appears': 985,
#  'flowers': 986,
#  'added': 987,
#  'tops': 988,
#  'shifts': 989,
#  'drunk': 990,
#  'pierced': 991,
#  'reckoned': 992,
#  'stands': 993,
#  'music': 994,
#  'from': 995,
#  'perfumes': 996,
#  'wrack': 997,
#  'female': 998,
#  'durst': 999,
#  ...}

# %%
wordclouds = states_to_wordclouds(shakespearean_hmm, shakespeare_hmm.token2index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-63d0520d9408> in <module>()
# ----> 1 wordclouds = states_to_wordclouds(shakespearean_hmm, shakespeare_hmm.token2index)
#
# ~/Documents/cs155/project3/Release/HMM_helper.py in states_to_wordclouds(hmm, obs_map, max_words, show)
#      75         sentence_str = ' '.join(sentence)
#      76
# ---> 77         wordclouds.append(text_to_wordcloud(sentence_str, max_words=max_words, title='State %d' % i, show=show))
#      78
#      79     return wordclouds
#
# ~/Documents/cs155/project3/Release/HMM_helper.py in text_to_wordcloud(text, max_words, title, show)
#      41                           max_words=max_words,
#      42                           background_color='white',
# ---> 43                           mask=mask()).generate(text)
#      44
#      45     # Show the image.
#
# ~/Documents/cs155/project3/tensorflow/lib64/python3.6/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     569         self
#     570         """
# --> 571         return self.generate_from_text(text)
#     572
#     573     def _check_generated(self):
#
# ~/Documents/cs155/project3/tensorflow/lib64/python3.6/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     551         """
#     552         words = self.process_text(text)
# --> 553         self.generate_from_frequencies(words)
#     554         return self
#     555
#
# ~/Documents/cs155/project3/tensorflow/lib64/python3.6/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     349         if len(frequencies) <= 0:
#     350             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 351                              "got %d." % len(frequencies))
#     352         frequencies = frequencies[:self.max_words]
#     353
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.
